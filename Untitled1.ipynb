# %% [markdown]
# <a href="https://colab.research.google.com/github/ArunBytes/Python_Basic/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def addition(x, y):
  a = x
  b = y
  c = a+b
  print(c)
addition(5,5)
# Out:
# 10

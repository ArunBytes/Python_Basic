# %% [markdown]
# <a href="https://colab.research.google.com/github/ArunBytes/Python_Basic/blob/main/Python01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Name = "Arun"

if Name == "Arun" :
  print("That is my Name")
else :
  print("that is not my name")
# Out:
# That is my Name

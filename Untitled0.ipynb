# %% [markdown]
# <a href="https://colab.research.google.com/github/ArunBytes/Python_Basic/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from os import remove
Car = { "BMW" : "AuDi", "Virtus" : "Skoda", "Thar" : "Jeep",}
print(Car)
print(type(Car))
print(len(Car))
# Out:
# {'BMW': 'AuDi', 'Virtus': 'Skoda', 'Thar': 'Jeep'}
# <class 'dict'>
# 3

# %%
car = { "Aulto" : "Nano"}
print(car)
# Out:
# {'Aulto': 'Nano'}

# %%
Car.pop("BMW")
print(Car)
# Out:
# {'Virtus': 'Skoda', 'Thar': 'Jeep'}

# %%
cars = {**Car,  **car}
print(cars)
# Out:
# {'Virtus': 'Skoda', 'Thar': 'Jeep', 'Aulto': 'Nano'}
